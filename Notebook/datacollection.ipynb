# %%
import sys

print(sys.executable)
print(sys.version)
# Out:
# c:\Users\Priya\OneDrive\Documents\weather_forecaster_Ml\my_venv\Scripts\python.exe
# 3.14.5 (tags/v3.14.5:5607950, May 10 2026, 10:43:50) [MSC v.1944 64 bit (AMD64)]

# %%
import pandas as pd

df = pd.read_parquet("../data/raw_data/daily_weather.parquet")
df.head()
# Out:
#   station_id city_name       date  season  avg_temp_c  min_temp_c  max_temp_c  \
# 0      41515  Asadabad 1957-07-01  Summer        27.0        21.1        35.6
# 1      41515  Asadabad 1957-07-02  Summer        22.8        18.9        32.2
# 2      41515  Asadabad 1957-07-03  Summer        24.3        16.7        35.6
# 3      41515  Asadabad 1957-07-04  Summer        26.6        16.1        37.8
# 4      41515  Asadabad 1957-07-05  Summer        30.8        20.0        41.7
#
#    precipitation_mm  snow_depth_mm  avg_wind_dir_deg  avg_wind_speed_kmh  \
# 0               0.0            NaN               NaN                 NaN
# 1               0.0            NaN               NaN                 NaN
# 2               1.0            NaN               NaN                 NaN
# 3               4.1            NaN               NaN                 NaN
# 4               0.0            NaN               NaN                 NaN
#
#    peak_wind_gust_kmh  avg_sea_level_pres_hpa  sunshine_total_min
# 0                 NaN                     NaN                 NaN
# 1                 NaN                     NaN                 NaN
# 2                 NaN                     NaN                 NaN
# 3                 NaN                     NaN                 NaN
# 4                 NaN                     NaN                 NaN

# %%
print("Dataset Shape:", df.shape)
# Out:
# Dataset Shape: (27635763, 14)

# %%
print("Number of Rows:", df.shape[0])
print("Number of Columns:", df.shape[1])
# Out:
# Number of Rows: 27635763
# Number of Columns: 14

# %%
print("Column Names:")
print(df.columns.tolist())
# Out:
# Column Names:
# ['station_id', 'city_name', 'date', 'season', 'avg_temp_c', 'min_temp_c', 'max_temp_c', 'precipitation_mm', 'snow_depth_mm', 'avg_wind_dir_deg', 'avg_wind_speed_kmh', 'peak_wind_gust_kmh', 'avg_sea_level_pres_hpa', 'sunshine_total_min']

# %%
df.dtypes
# Out:
# station_id                      category
# city_name                       category
# date                      datetime64[us]
# season                          category
# avg_temp_c                       float64
# min_temp_c                       float64
# max_temp_c                       float64
# precipitation_mm                 float64
# snow_depth_mm                    float64
# avg_wind_dir_deg                 float64
# avg_wind_speed_kmh               float64
# peak_wind_gust_kmh               float64
# avg_sea_level_pres_hpa           float64
# sunshine_total_min               float64
# dtype: object

# %%
missing_values = df.isnull().sum()

print(missing_values)
# Out:
# station_id                       0
# city_name                    13993
# date                             0
# season                           0
# avg_temp_c                 6230907
# min_temp_c                 5718229
# max_temp_c                 5539346
# precipitation_mm           6642500
# snow_depth_mm             24208615
# avg_wind_dir_deg          24183195
# avg_wind_speed_kmh        22350295
# peak_wind_gust_kmh        26514277
# avg_sea_level_pres_hpa    23618606
# sunshine_total_min        26614302
# dtype: int64

# %%
# Calculate missing value percentages

missing_summary = pd.DataFrame({
    "Missing Values": df.isnull().sum(),
    "Missing Percentage": (df.isnull().sum() / len(df)) * 100
})

missing_summary = missing_summary.sort_values(
    by="Missing Percentage",
    ascending=False
)

missing_summary
# Out:
#                         Missing Values  Missing Percentage
# sunshine_total_min            26614302           96.303844
# peak_wind_gust_kmh            26514277           95.941903
# snow_depth_mm                 24208615           87.598866
# avg_wind_dir_deg              24183195           87.506884
# avg_sea_level_pres_hpa        23618606           85.463919
# avg_wind_speed_kmh            22350295           80.874536
# precipitation_mm               6642500           24.035884
# avg_temp_c                     6230907           22.546535
# min_temp_c                     5718229           20.691410
# max_temp_c                     5539346           20.044122
# city_name                        13993            0.050634
# date                                 0            0.000000
# station_id                           0            0.000000
# season                               0            0.000000

# %%
# Check duplicate rows

duplicate_count = df.duplicated().sum()

print("Total Duplicate Rows:", duplicate_count)
# Out:
# Total Duplicate Rows: 21280

# %%
# Check data types

df.dtypes
# Out:
# station_id                      category
# city_name                       category
# date                      datetime64[us]
# season                          category
# avg_temp_c                       float64
# min_temp_c                       float64
# max_temp_c                       float64
# precipitation_mm                 float64
# snow_depth_mm                    float64
# avg_wind_dir_deg                 float64
# avg_wind_speed_kmh               float64
# peak_wind_gust_kmh               float64
# avg_sea_level_pres_hpa           float64
# sunshine_total_min               float64
# dtype: object
